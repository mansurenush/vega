# %%
# !pip install navec slovnet pymystem3 spacy gdown
# Out:
# Requirement already satisfied: navec in /opt/conda/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: slovnet in /opt/conda/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: pymystem3 in /opt/conda/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: spacy in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from navec) (1.24.3)
# Requirement already satisfied: razdel in /opt/conda/lib/python3.10/site-packages (from slovnet) (0.5.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from pymystem3) (2.31.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy) (68.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->pymystem3) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->pymystem3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->pymystem3) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->pymystem3) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests->pymystem3) (1.7.1)
# Installing collected packages: gdown
# Successfully installed gdown-4.7.1

# %%
# !wget https://storage.yandexcloud.net/natasha-navec/packs/navec_news_v1_1B_250K_300d_100q.tar
# !wget https://storage.yandexcloud.net/natasha-slovnet/packs/slovnet_ner_news_v1.tar
# Out:
# --2023-11-21 09:55:03--  https://storage.yandexcloud.net/natasha-navec/packs/navec_news_v1_1B_250K_300d_100q.tar
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26634240 (25M) [application/x-tar]
# Saving to: ‘navec_news_v1_1B_250K_300d_100q.tar.1’
#
# navec_news_v1_1B_25 100%[===================>]  25.40M  8.71MB/s    in 2.9s
#
# 2023-11-21 09:55:07 (8.71 MB/s) - ‘navec_news_v1_1B_250K_300d_100q.tar.1’ saved [26634240/26634240]
#
# --2023-11-21 09:55:08--  https://storage.yandexcloud.net/natasha-slovnet/packs/slovnet_ner_news_v1.tar
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2385920 (2.3M) [application/octet-stream]
# Saving to: ‘slovnet_ner_news_v1.tar.1’
#
# slovnet_ner_news_v1 100%[===================>]   2.28M  1.84MB/s    in 1.2s
#
# 2023-11-21 09:55:10 (1.84 MB/s) - ‘slovnet_ner_news_v1.tar.1’ saved [2385920/2385920]

# %%
# !gdown --id 1DNilv-qiNFjCSOhBFZE4JjGbSrAYZ9UP --output "all brands - Sheet2.csv"
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1DNilv-qiNFjCSOhBFZE4JjGbSrAYZ9UP
# To: /kaggle/working/all brands - Sheet2.csv
# 100%|██████████████████████████████████████| 12.2k/12.2k [00:00<00:00, 40.8MB/s]

# %%
import pickle
import pandas as pd
import numpy as np
import re

from navec import Navec
from slovnet import NER
from razdel import sentenize

from pymystem3 import Mystem
import spacy
import nltk

from tqdm import tqdm

# %%
import os
os.listdir('/kaggle/input/')
# Out:
# ['sentiment', 'brands-without-rx', 'allbrands']

# %%
with open('../input/sentiment/messages_many.pkl', 'rb') as file:

    mes_many = pickle.load(file)

# %%
mentions = pd.read_csv('../input/sentiment/mentions.csv', index_col = 0)
mentions = mentions[mentions['issuerid'] > 0]
mentions = mentions.rename(columns={'messageid': 'MessageID'})

# %%
sentiment = pd.read_csv('../input/sentiment/sentiment.csv', index_col = 0)
sentiment = sentiment[sentiment['issuerid'] > 0]

# %%
sentiment
# Out:
#       MessageID   ChannelID  issuerid  SentimentScore
# 74          556  1155666448       150               3
# 75          559  1155666448       129               3
# 76          561  1155666448        99               4
# 79          562  1155666448        99               4
# 80          565  1155666448       150               3
# ...         ...         ...       ...             ...
# 4374     237595  1203560567        26               4
# 4375     237600  1203560567        53               4
# 4376     237650  1203560567        53               3
# 4377     237675  1203560567       129               4
# 4378     237677  1203560567        53               2
#
# [2760 rows x 4 columns]

# %%
mes_many
# Out:
#         MessageID   ChannelID           DateAdded          DatePosted  \
# 0               1  1001029560 2021-02-06 00:52:00 2015-11-18 19:09:32
# 1               2  1001029560 2021-02-06 00:52:00 2015-11-23 13:02:29
# 2               3  1001029560 2021-02-06 00:52:00 2015-11-23 13:04:00
# 3               4  1001029560 2021-02-06 00:52:00 2015-11-23 13:04:16
# 4               5  1001029560 2021-02-06 00:52:00 2015-11-23 13:04:41
# ...           ...         ...                 ...                 ...
# 594604       1435  1565800335 2023-04-14 18:45:36 2023-04-14 07:30:00
# 594605       1437  1565800335 2023-04-17 14:25:45 2023-04-15 07:30:00
# 594606       1439  1565800335 2023-04-17 14:25:45 2023-04-16 19:00:02
# 594607       1440  1565800335 2023-04-17 14:25:45 2023-04-17 10:15:36
# 594608       1441  1565800335 2023-04-17 14:25:45 2023-04-17 12:00:07
#
#                                               MessageText  IsForward
# 0                                                              False
# 1       http://bcs-express.ru/investidei/usdrubukoil/n...      False
# 2       http://bcs-express.ru/novosti-i-analitika/inte...      False
# 3       http://bcs-express.ru/novosti-i-analitika/priz...      False
# 4       http://bcs-express.ru/novosti-i-analitika/kak-...      False
# ...                                                   ...        ...
# 594604  "​🖥  Softline / Noventiq Holdings (SFTL) - что...      False
# 594605  ​🔬 IPO ЦГМК Genetico, разбор компании  ▫️Капит...      False
# 594606  "Как купить участок за 3% от кадастровой стоим...      False
# 594607  ⚡ Актуальные идеи на российском рынке  Практич...      False
# 594608  "Постоянно получаю от вас вопросы по типу ""На...      False
#
# [594609 rows x 6 columns]

# %%
mes_0 = pd.read_excel('../input/sentiment/messages_0.xlsx', sheet_name=None)
for sheet_name in mes_0.keys():
    mes_0[sheet_name]['ticker'] = sheet_name
mes_0 = pd.concat(mes_0, ignore_index=True)
# Out:
# /tmp/ipykernel_47/910650669.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mes_0 = pd.concat(mes_0, ignore_index=True)

# %%
mes_1 = pd.read_excel('../input/sentiment/messages_1.xlsx', sheet_name=None)
for sheet_name in mes_1.keys():
    mes_1[sheet_name]['ticker'] = sheet_name
mes_1 = pd.concat(mes_1, ignore_index=True)
# Out:
# /tmp/ipykernel_47/1859392702.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mes_1 = pd.concat(mes_1, ignore_index=True)

# %%
mes_2 = pd.read_excel('../input/sentiment/messages_2.xlsx', sheet_name=None)
for sheet_name in mes_2.keys():
    mes_2[sheet_name]['ticker'] = sheet_name
mes_2 = pd.concat(mes_2, ignore_index=True)
# Out:
# /tmp/ipykernel_47/735663529.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mes_2 = pd.concat(mes_2, ignore_index=True)

# %%
mes_012 = pd.concat([mes_0, mes_1, mes_2], ignore_index=True)

# %%
mes_012
# Out:
#                                             MessageText          DatePosted  \
# 0     ❗️🛢🇷🇺#газ #россия #макро  Новак: запасы газа н... 2021-12-29 08:51:59
# 1     ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупк... 2021-12-23 13:38:22
# 2     🟢 НОВАТЭК договорился о поставках низкоуглерод... 2021-12-23 13:31:19
# 3     ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 4     🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК поста... 2021-12-23 07:47:03
# ...                                                 ...                 ...
# 7533  🔦 Фокус недели #ФН   Сегодня 🖨 Мосбиржа (MOEX)... 2021-12-02 08:01:34
# 7534  🗓КАЛЕНДАРЬ НА СЕГОДНЯ - 2021.12.02  🔥ГОРЯЧЕЕ 🛢... 2021-12-02 06:30:24
# 7535  "✅ Главное по секторам российского рынка  ☢️ У... 2021-12-01 19:00:00
# 7536     🇷🇺#AFKS #отчетность #прогноз  Газпромбанк: АФК 2021-12-01 10:08:19
# 7537  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
#
#       MyScore MessageID   ChannelID                    ChannelURL  \
# 0         NaN    172344  1203560567      https://t.me/markettwits
# 1         NaN     13848  1300011741       https://t.me/finamalert
# 2         NaN      2473  1239405989  https://t.me/SberInvestments
# 3         NaN     10636  1075101206          https://t.me/AK47pfl
# 4         NaN    171722  1203560567      https://t.me/markettwits
# ...       ...       ...         ...                           ...
# 7533      NaN     29123  1197210433        https://t.me/cbrstocks
# 7534      NaN    168528  1203560567      https://t.me/markettwits
# 7535      NaN     10455  1075101206          https://t.me/AK47pfl
# 7536      NaN    168347  1203560567      https://t.me/markettwits
# 7537      NaN     29069  1197210433        https://t.me/cbrstocks
#
#                             MessageLink ticker
# 0       https://t.me/markettwits/172344   nvtk
# 1         https://t.me/finamalert/13848   nvtk
# 2     https://t.me/SberInvestments/2473   nvtk
# 3            https://t.me/AK47pfl/10636   nvtk
# 4       https://t.me/markettwits/171722   nvtk
# ...                                 ...    ...
# 7533       https://t.me/cbrstocks/29123   afks
# 7534    https://t.me/markettwits/168528   afks
# 7535         https://t.me/AK47pfl/10455   afks
# 7536    https://t.me/markettwits/168347   afks
# 7537       https://t.me/cbrstocks/29069   afks
#
# [7538 rows x 8 columns]

# %%
text_ = 'ЕПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупка ⬆️ Инвестиционный горизонт 1-2 месяца Цена входа - тек. рыночная Цель 2 080 руб. Потенциальная доходность на сделку 22% Объем входа 5% Стоп-приказ 1 500 руб.   Технический анализ Бумага оттолкнулась от уровня поддержки. Открывать позиции рекомендуем от текущих уровней с целью 2 080 рублей. При покупке на 5% от объема портфеля и выставлении стоп-заявки на уровне 1500 рублей риск на портфель составит 0,60%. Соотношение прибыль/риск составляет 1,9.   Фундаментальный фактор Основным позитивным моментом в инвестиционном кейсе «НОВАТЭКа» является его программа развития в сфере СПГ. К 2030 году компания планирует увеличить производство СПГ в 2,9–3,6 раза до 57–70 млн тонн. Благодаря стабильно растущему спросу, нет сомнений, что «НОВАТЭК» найдет покупателей на свою продукцию. При этом значительные налоговые льготы и низкие расходы на добычу и сжижение газа делают российский СПГ одним из самых конкурентоспособных в мире. В текущем году «НОВАТЭК», как и все нефтегазовые компании, показывает восстановление финансовых результатов. Причинами для этого стали рост цен на нефть и СПГ, развитие проекта «Ямал СПГ», а также небольшое увеличение объемов добычи углеводородов. На этом фоне мы полагаем, что в 2021 году все основные финансовые показатели «НОВАТЭКа» будут рекордными, как и в новом 2022 году.'

navec = Navec.load('navec_news_v1_1B_250K_300d_100q.tar')
ner = NER.load('slovnet_ner_news_v1.tar')
ner.navec(navec)
markup_ = ner(text_)
print(markup_.text[15:38])
print(text_[15:38])
# Out:
# Тикер NVTK Рекомендация
# Тикер NVTK Рекомендация

# %%
mes_cp = mes_012[:10]
mes_cp = mes_cp[['MessageText', 'DatePosted','ticker']]

# %%
# %%timeit
mes_cp = mes_012[:10]
mes_cp = mes_cp[['MessageText', 'DatePosted','ticker']]
for i in range(mes_cp.shape[0]):
    markup = ner(mes_cp.MessageText[i])
    string = set()
    rows_list = []
    MT = []
    cur_start = 0
    for span in markup.spans:  
        if span.type == 'ORG':
            word = (markup.text[span.start:span.stop]).lower()
            if word not in string: # долгая проверка
                string.add(word)
                MT.append(mes_cp.MessageText[i][cur_start:span.stop])
                cur_start = span.stop
    DP = mes_cp.DatePosted[i]
    for s in string:
        c = 0
        new_data = {'MessageText': MT[c], 'DatePosted': DP, 'ticker':s}
        rows_list.append(new_data)
        c+=1
    df = pd.DataFrame(rows_list)
    mes_cp = pd.concat([mes_cp, df], ignore_index=True)
# Out:
# 187 ms ± 3.02 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
mes_cp
# Out:
#                                          MessageText          DatePosted  \
# 0  ❗️🛢🇷🇺#газ #россия #макро  Новак: запасы газа н... 2021-12-29 08:51:59
# 1  ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупк... 2021-12-23 13:38:22
# 2  🟢 НОВАТЭК договорился о поставках низкоуглерод... 2021-12-23 13:31:19
# 3  ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 4  🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК поста... 2021-12-23 07:47:03
# 5  ✅ Главное по секторам российского рынка  ☢️ Ур... 2021-12-22 19:29:59
# 6  💥🇷🇺🇩🇪#NVTK #германия #аммиак Новатэк и немецка... 2021-12-22 13:35:02
# 7  #NVTK ⛽️ Новатэк (NVTK) и Uniper подписали сог... 2021-12-22 13:34:39
# 8  🟢 НОВАТЭК утвердил программу выкупа акций на $... 2021-12-20 15:37:05
# 9  🇷🇺#NVTK #buyback  Новатэк, в период с 13 по 17... 2021-12-20 15:22:15
#
#   ticker
# 0   nvtk
# 1   nvtk
# 2   nvtk
# 3   nvtk
# 4   nvtk
# 5   nvtk
# 6   nvtk
# 7   nvtk
# 8   nvtk
# 9   nvtk

# %% [markdown]
# ## #todo lemma + word in issuers

# %%
# lemma только для русских слов тк это сущетсвительное ✅
# потом уже делать in issuers ✅ ~
# объеденить issuers компании в строку и делать word substring
# делить по предложениям а не по spans index ✅

# %%
text = "Красивая SberCIB"
m = Mystem() #pymystem3
lemmas = m.lemmatize(text)
lemmas
# Out:
# Installing mystem to /root/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.1-linux-64bit.tar.gz
# ['красивый', ' ', 'SberCIB', '\n']

# %%
#%%timeit
mes_cp = mes_012[:20]
mes_cp = mes_cp[['MessageText', 'DatePosted','ticker']]
for i in range(mes_cp.shape[0]):
    markup = ner(mes_cp.MessageText[i])
    string = set()
    rows_list = []
    MT = []
    cur_start = 0
    for span in markup.spans:  
        if span.type == 'ORG':
            word = (markup.text[span.start:span.stop]).lower()
            word = m.lemmatize(word)[0]
            if word not in string: # долгая проверка
                string.add(word)
                MT.append(mes_cp.MessageText[i][cur_start:span.stop])
                cur_start = span.stop
    DP = mes_cp.DatePosted[i]
    for s in string:
        c = 0
        new_data = {'MessageText': MT[c], 'DatePosted': DP, 'ticker':s}
        rows_list.append(new_data)
        c+=1
    df = pd.DataFrame(rows_list)
    mes_cp = pd.concat([mes_cp, df], ignore_index=True)

# %%
mes_cp
# Out:
#                                           MessageText          DatePosted  \
# 0   ❗️🛢🇷🇺#газ #россия #макро  Новак: запасы газа н... 2021-12-29 08:51:59
# 1   ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупк... 2021-12-23 13:38:22
# 2   🟢 НОВАТЭК договорился о поставках низкоуглерод... 2021-12-23 13:31:19
# 3   ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 4   🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК поста... 2021-12-23 07:47:03
# 5   ✅ Главное по секторам российского рынка  ☢️ Ур... 2021-12-22 19:29:59
# 6   💥🇷🇺🇩🇪#NVTK #германия #аммиак Новатэк и немецка... 2021-12-22 13:35:02
# 7   #NVTK ⛽️ Новатэк (NVTK) и Uniper подписали сог... 2021-12-22 13:34:39
# 8   🟢 НОВАТЭК утвердил программу выкупа акций на $... 2021-12-20 15:37:05
# 9   🇷🇺#NVTK #buyback  Новатэк, в период с 13 по 17... 2021-12-20 15:22:15
# 10           #NVTK ⛽️ Новатэк с 13 по 17 декабря выку 2021-12-20 14:52:41
# 11  "💥🛢🇷🇺#NVTK ПРАВИТЕЛЬСТВО ПЛАНИРУЕТ ПРЕДОСТАВИТ... 2021-12-20 14:43:01
# 12  💥🇷🇺#NVTK #buyback СД НОВАТЭКА ОДОБРИЛ НОВУЮ ПР... 2021-12-17 14:49:11
# 13  #NVTK ⚡️ Новатэк одобрил новую программу байбэ... 2021-12-17 14:48:20
# 14  🛢🇷🇺#газ #россия #NVTK  Новатэк не стремится к ... 2021-12-15 12:00:54
# 15  #NVTK ⛽️ Новатэк (NVTK) не стремится получить ... 2021-12-15 12:00:31
# 16  "🛢🇷🇺#NVTK #спг ""Ямал СПГ"" с момента запуск ч... 2021-12-15 11:54:14
# 17  🇷🇺#NVTK Новатэк сохраняет планы начать произво... 2021-12-15 11:25:00
# 18  #LKOH #NVTK 🔮📈 Ренкап повысил рекомендацию по ... 2021-12-10 10:58:48
# 19  "✅ Главное по секторам российского рынка  🛢 Не... 2021-12-08 19:30:00
# 20  ❗️🛢🇷🇺#газ #россия #макро  Новак: запасы газа н... 2021-12-29 08:51:59
# 21                                      ПАО «НОВАТЭК» 2021-12-23 13:38:22
# 22                                      ПАО «НОВАТЭК» 2021-12-23 13:38:22
# 23                                          🟢 НОВАТЭК 2021-12-23 13:31:19
# 24                                          🟢 НОВАТЭК 2021-12-23 13:31:19
# 25                                          🟢 НОВАТЭК 2021-12-23 13:31:19
# 26  ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 27  ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 28  ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 29           🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК 2021-12-23 07:47:03
# 30           🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК 2021-12-23 07:47:03
# 31  ✅ Главное по секторам российского рынка  ☢️ Ур... 2021-12-22 19:29:59
# 32  ✅ Главное по секторам российского рынка  ☢️ Ур... 2021-12-22 19:29:59
# 33  ✅ Главное по секторам российского рынка  ☢️ Ур... 2021-12-22 19:29:59
# 34               💥🇷🇺🇩🇪#NVTK #германия #аммиак Новатэк 2021-12-22 13:35:02
# 35               💥🇷🇺🇩🇪#NVTK #германия #аммиак Новатэк 2021-12-22 13:35:02
# 36                            #NVTK ⛽️ Новатэк (NVTK) 2021-12-22 13:34:39
# 37                            #NVTK ⛽️ Новатэк (NVTK) 2021-12-22 13:34:39
# 38                            #NVTK ⛽️ Новатэк (NVTK) 2021-12-22 13:34:39
# 39                                          🟢 НОВАТЭК 2021-12-20 15:37:05
# 40                                          🟢 НОВАТЭК 2021-12-20 15:37:05
# 41                          🇷🇺#NVTK #buyback  Новатэк 2021-12-20 15:22:15
# 42                                              #NVTK 2021-12-20 14:52:41
# 43                                              #NVTK 2021-12-20 14:52:41
# 44  "💥🛢🇷🇺#NVTK ПРАВИТЕЛЬСТВО ПЛАНИРУЕТ ПРЕДОСТАВИТ... 2021-12-20 14:43:01
# 45  "💥🛢🇷🇺#NVTK ПРАВИТЕЛЬСТВО ПЛАНИРУЕТ ПРЕДОСТАВИТ... 2021-12-20 14:43:01
# 46                                              #NVTK 2021-12-17 14:48:20
# 47                                              #NVTK 2021-12-17 14:48:20
# 48                     🛢🇷🇺#газ #россия #NVTK  Новатэк 2021-12-15 12:00:54
# 49                     🛢🇷🇺#газ #россия #NVTK  Новатэк 2021-12-15 12:00:54
# 50                     🛢🇷🇺#газ #россия #NVTK  Новатэк 2021-12-15 12:00:54
# 51                            #NVTK ⛽️ Новатэк (NVTK) 2021-12-15 12:00:31
# 52                          "🛢🇷🇺#NVTK #спг ""Ямал СПГ 2021-12-15 11:54:14
# 53                                            🇷🇺#NVTK 2021-12-15 11:25:00
# 54                                            🇷🇺#NVTK 2021-12-15 11:25:00
# 55  #LKOH #NVTK 🔮📈 Ренкап повысил рекомендацию по ... 2021-12-10 10:58:48
# 56  #LKOH #NVTK 🔮📈 Ренкап повысил рекомендацию по ... 2021-12-10 10:58:48
# 57  "✅ Главное по секторам российского рынка  🛢 Не... 2021-12-08 19:30:00
# 58  "✅ Главное по секторам российского рынка  🛢 Не... 2021-12-08 19:30:00
#
#           ticker
# 0           nvtk
# 1           nvtk
# 2           nvtk
# 3           nvtk
# 4           nvtk
# 5           nvtk
# 6           nvtk
# 7           nvtk
# 8           nvtk
# 9           nvtk
# 10          nvtk
# 11          nvtk
# 12          nvtk
# 13          nvtk
# 14          nvtk
# 15          nvtk
# 16          nvtk
# 17          nvtk
# 18          nvtk
# 19          nvtk
# 20          nvtk
# 21       новатэк
# 22           пао
# 23        uniper
# 24       sbercib
# 25       новатэк
# 26       новатэк
# 27        uniper
# 28       мечесть
# 29       новатэк
# 30             ъ
# 31   казатомпром
# 32       газпром
# 33            цб
# 34        uniper
# 35       новатэк
# 36        uniper
# 37          nvtk
# 38       новатэк
# 39       sbercib
# 40       новатэк
# 41       новатэк
# 42          nvtk
# 43       новатэк
# 44        арктик
# 45  распоряжение
# 46          nvtk
# 47       новатэк
# 48      роснефть
# 49       газпром
# 50       новатэк
# 51          nvtk
# 52          ямал
# 53          nvtk
# 54       новатэк
# 55       новатэк
# 56        лукойл
# 57          илим
# 58       мировой

# %% [markdown]
# ### Sentence tokenizer (razdel/nltk)

# %%
text__ = 'ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупка ⬆️ Инвестиционный горизонт 1-2 месяца Цена входа - тек. рыночная Цель 2 080 руб. Потенциальная доходность на сделку 22% Объем входа 5% Стоп-приказ 1 500 руб.   Технический анализ Бумага оттолкнулась от уровня поддержки. Открывать позиции рекомендуем от текущих уровней с целью 2 080 рублей. При покупке на 5% от объема портфеля и выставлении стоп-заявки на уровне 1500 рублей риск на портфель составит 0,60%. Соотношение прибыль/риск составляет 1,9.   Фундаментальный фактор Основным позитивным моментом в инвестиционном кейсе «НОВАТЭКа» является его программа развития в сфере СПГ. К 2030 году компания планирует увеличить производство СПГ в 2,9–3,6 раза до 57–70 млн тонн. Благодаря стабильно растущему спросу, нет сомнений, что «НОВАТЭК» найдет покупателей на свою продукцию. При этом значительные налоговые льготы и низкие расходы на добычу и сжижение газа делают российский СПГ одним из самых конкурентоспособных в мире. В текущем году «НОВАТЭК», как и все нефтегазовые компании, показывает восстановление финансовых результатов. Причинами для этого стали рост цен на нефть и СПГ, развитие проекта «Ямал СПГ», а также небольшое увеличение объемов добычи углеводородов. На этом фоне мы полагаем, что в 2021 году все основные финансовые показатели «НОВАТЭКа» будут рекордными, как и в новом 2022 году.  ✅ Пишите, есл'

mmm = list(sentenize(text__))
mmm
# Out:
# [Substring(0,
#            128,
#            'ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупка ⬆️ Инвестиционный горизонт 1-2 месяца Цена входа - тек. рыночная Цель 2 080 руб.'),
#  Substring(129,
#            205,
#            'Потенциальная доходность на сделку 22% Объем входа 5% Стоп-приказ 1 500 руб.'),
#  Substring(208,
#            267,
#            'Технический анализ Бумага оттолкнулась от уровня поддержки.'),
#  Substring(268,
#            338,
#            'Открывать позиции рекомендуем от текущих уровней с целью 2 080 рублей.'),
#  Substring(339,
#            456,
#            'При покупке на 5% от объема портфеля и выставлении стоп-заявки на уровне 1500 рублей риск на портфель составит 0,60%.'),
#  Substring(457, 497, 'Соотношение прибыль/риск составляет 1,9.'),
#  Substring(500,
#            630,
#            'Фундаментальный фактор Основным позитивным моментом в инвестиционном кейсе «НОВАТЭКа» является его программа развития в сфере СПГ.'),
#  Substring(631,
#            722,
#            'К 2030 году компания планирует увеличить производство СПГ в 2,9–3,6 раза до 57–70 млн тонн.'),
#  Substring(723,
#            826,
#            'Благодаря стабильно растущему спросу, нет сомнений, что «НОВАТЭК» найдет покупателей на свою продукцию.'),
#  Substring(827,
#            973,
#            'При этом значительные налоговые льготы и низкие расходы на добычу и сжижение газа делают российский СПГ одним из самых конкурентоспособных в мире.'),
#  Substring(974,
#            1082,
#            'В текущем году «НОВАТЭК», как и все нефтегазовые компании, показывает восстановление финансовых результатов.'),
#  Substring(1083,
#            1221,
#            'Причинами для этого стали рост цен на нефть и СПГ, развитие проекта «Ямал СПГ», а также небольшое увеличение объемов добычи углеводородов.'),
#  Substring(1222,
#            1352,
#            'На этом фоне мы полагаем, что в 2021 году все основные финансовые показатели «НОВАТЭКа» будут рекордными, как и в новом 2022 году.'),
#  Substring(1354, 1367, '✅ Пишите, есл')]

# %%
sent_tokenizer = nltk.tokenize.PunktSentenceTokenizer()
text = 'ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупка ⬆️ Инвестиционный горизонт 1-2 месяца Цена входа - тек. рыночная Цель 2 080 руб. Потенциальная доходность на сделку 22% Объем входа 5% Стоп-приказ 1 500 руб.   Технический анализ Бумага оттолкнулась от уровня поддержки. Открывать позиции рекомендуем от текущих уровней с целью 2 080 рублей. При покупке на 5% от объема портфеля и выставлении стоп-заявки на уровне 1500 рублей риск на портфель составит 0,60%. Соотношение прибыль/риск составляет 1,9.   Фундаментальный фактор Основным позитивным моментом в инвестиционном кейсе «НОВАТЭКа» является его программа развития в сфере СПГ. К 2030 году компания планирует увеличить производство СПГ в 2,9–3,6 раза до 57–70 млн тонн. Благодаря стабильно растущему спросу, нет сомнений, что «НОВАТЭК» найдет покупателей на свою продукцию. При этом значительные налоговые льготы и низкие расходы на добычу и сжижение газа делают российский СПГ одним из самых конкурентоспособных в мире. В текущем году «НОВАТЭК», как и все нефтегазовые компании, показывает восстановление финансовых результатов. Причинами для этого стали рост цен на нефть и СПГ, развитие проекта «Ямал СПГ», а также небольшое увеличение объемов добычи углеводородов. На этом фоне мы полагаем, что в 2021 году все основные финансовые показатели «НОВАТЭКа» будут рекордными, как и в новом 2022 году.  ✅ Пишите, есл'
#m = sent_tokenizer.tokenize(text)

# %%
#%%timeit
m = Mystem()
mes_cp = mes_012[:1000]
mes_cp = mes_cp[['MessageText', 'DatePosted','ticker']]

for i in tqdm(range(mes_cp.shape[0])):
    sentences = list(sentenize(mes_cp.MessageText[i]))
    markup = ner(mes_cp.MessageText[i])
    string = set()
    
    MT = []
    for span in markup.spans:  
        if span.type == 'ORG':
            word = (markup.text[span.start:span.stop]) #.lower()
            word = m.lemmatize(word)[0]
            if word not in string: # долгая проверка
                string.add(word)
                ### text boundaries
                for s in sentences:
                    rr = []
                    for r in s: # (rangeL:rangeR), sentence
                        rr.append(r)    
                    if (span.start >= rr[0] and span.stop <= rr[1]):
                        MT.append(rr[2])   
                    
    rows_list = []            
    DP = mes_cp.DatePosted[i]
    for s in string:
        c = 0
        new_data = {'MessageText': MT[c], 'DatePosted': DP, 'ticker':s}
        rows_list.append(new_data)
        c+=1
    df = pd.DataFrame(rows_list)
    mes_cp = pd.concat([mes_cp, df], ignore_index=True)
# Out:
# 100%|██████████| 1000/1000 [00:26<00:00, 38.44it/s]

# %%
mes_cp
# Out:
#                                             MessageText          DatePosted  \
# 0     ❗️🛢🇷🇺#газ #россия #макро  Новак: запасы газа н... 2021-12-29 08:51:59
# 1     ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупк... 2021-12-23 13:38:22
# 2     🟢 НОВАТЭК договорился о поставках низкоуглерод... 2021-12-23 13:31:19
# 3     ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 4     🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК поста... 2021-12-23 07:47:03
# ...                                                 ...                 ...
# 4991  Канада выступает за отключение РФ от  SWIFT  Е... 2022-02-26 09:04:50
# 4992  Канада выступает за отключение РФ от  SWIFT  Е... 2022-02-26 09:04:50
# 4993  Канада выступает за отключение РФ от  SWIFT  Е... 2022-02-26 09:04:50
# 4994  Канада выступает за отключение РФ от  SWIFT  Е... 2022-02-26 09:04:50
# 4995  Канада выступает за отключение РФ от  SWIFT  Е... 2022-02-26 09:04:50
#
#           ticker
# 0           nvtk
# 1           nvtk
# 2           nvtk
# 3           nvtk
# 4           nvtk
# ...          ...
# 4991          цб
# 4992      севмаш
# 4993         свр
# 4994  совкомфлот
# 4995        FLOT
#
# [4996 rows x 3 columns]

# %% [markdown]
# ### brands - все issuers(кроме полных названий) с повторами.
# ### Идея прогнать алгоритм выше на всех 7.5к строках. получить столбец с ticker'ами. Для каждого тикера проверить not in brands: если true, то поместить его в stopwords.
# ### потом апргрейднуть алгоритм проверяя уже not in stopwords.

# %%
brands = pd.read_csv('../input/allbrands/all brands.csv') 
brands['abraudurso'] = brands['abraudurso'].str.lower()
brand_list = brands.abraudurso.tolist()
brand_list
# Out:
# ['abrd',
#  'acron',
#  'aeroflot',
#  'afks rx',
#  'aflt rx',
#  'agro rx',
#  'akrn rx',
#  'alnu rx',
#  'alrosa',
#  'alrosa',
#  'alrs rx',
#  'amez',
#  'ao fgc ues',
#  'aptk rx',
#  'aqua',
#  'arsa',
#  'arsagera(не встречал упоминаний)',
#  'assb',
#  'avan',
#  'avangard',
#  'bane rx',
#  'belon',
#  'belu rx',
#  'beluga',
#  'bisv                ',
#  'blng',
#  'bspb rx',
#  'cbom rx',
#  'central telegraph',
#  'chelyabinsk metallurgical plant',
#  'chelyabinsk pipe rolling plant',
#  'chep rx',
#  'cherkizovo',
#  'chmf rx',
#  'chmk rx',
#  'ckpz rx',
#  'cntl rx',
#  'credit bank',
#  'credit bank of moscow',
#  'dagestanskaya energosbytovaya',
#  'dasb',
#  'derzp',
#  'detsky mir',
#  'diod plant of ecological technics and ecomeals',
#  'diod rx',
#  'dsky rx',
#  'dvec',
#  'dzrd',
#  'eelt                ',
#  'electrozink',
#  'eltz rx                ',
#  'en+ group',
#  'en+ group plc',
#  'enel russia',
#  'enpg rx',
#  'enpl',
#  'enru rx',
#  'etln li',
#  'fees rx',
#  'fesco',
#  'fesh                ',
#  'five li',
#  'fixp rx',
#  'flot rx',
#  'gas-service',
#  'gaz-tec',
#  'gaza                ',
#  'gazp',
#  'gazp rx',
#  'gazprom',
#  'gazprom neft',
#  'gazs',
#  'gazt',
#  'gche rx ',
#  'globaltruck',
#  'gltr li',
#  'gmkn rx',
#  'grnt',
#  'gseis',
#  'gtl',
#  'gtlc ',
#  'gtrk                ',
#  'gtss',
#  'hhru rx',
#  'himcp rx',
#  'himprom',
#  'hydr rx',
#  'idvp',
#  'igst                ',
#  'inarctica',
#  'ingr',
#  'ingr rx',
#  'ingrad ',
#  'inter rao',
#  'invest-development',
#  'irao rx',
#  'irgz',
#  'irkt rx',
#  'irkutskenergo',
#  'iskj                ',
#  "izhstal'",
#  'kamaz ',
#  'kazanorgsintez',
#  'kazt',
#  'kbsb',
#  'kbsbp',
#  'kbtk',
#  'kgiw',
#  'kgkc',
#  'klsb',
#  'kmaz rx',
#  'kmez',
#  'kmtz                ',
#  'kogk                ',
#  'koks',
#  'korgok',
#  'korshunov mining plant',
#  'kostromskaya sbytovaya kompaniya',
#  'krsb',
#  'krsk-sbit',
#  'ksgr                ',
#  'ksk',
#  'ktk',
#  'ktsb',
#  'kuazot',
#  'kunf',
#  'kuzb rx',
#  'kuzbank',
#  'kuzocm',
#  'kvmz',
#  'kzms',
#  'kzos',
#  'lenzoloto',
#  'levenhuk',
#  'lkoh rx',
#  'lnta rx',
#  'lnzl',
#  'lpsb',
#  'lpsbg',
#  'lsrg rx',
#  'lvhk',
#  'magn rx',
#  'magnit ',
#  'magnitigorskiy metallurgicheskiy',
#  'mail li',
#  'mdmg rx',
#  'mechel',
#  'megafon',
#  'mfon rx',
#  'mgnt ',
#  'mgnt rx',
#  'mgnz',
#  'mgnzg',
#  'mgts rx ',
#  'misb',
#  'misbp',
#  'moex rx',
#  'mrku                ',
#  'msst',
#  'mstt',
#  'mtc',
#  'mtlr rx',
#  'mtlrp',
#  'mtss rx',
#  'multisistema',
#  'mvid rx',
#  'mvideo',
#  'nkhp',
#  'nlmk rx',
#  'nmtp',
#  'nnsb',
#  'nnsbp',
#  'nompp',
#  'nornickel ',
#  'novatek',
#  'npof',
#  'npofizika',
#  'nvtk rx',
#  'oao chelyabinsk forge-and-press plant',
#  'oao tmk',
#  'ogkb                ',
#  'okey rx',
#  'opin',
#  'ozon rx',
#  'pharmsynthez',
#  'phor rx',
#  'phosagro',
#  'pikk rx',
#  'pjsc krasny kotelshchik',
#  'plzl rx',
#  'poly rx',
#  'prfn rx            ',
#  'prmb',
#  'qiwi rx',
#  'quadra',
#  'rasp rx ',
#  'rdrb',
#  'rlmn',
#  'rollman',
#  'rosinter',
#  'rosn rx',
#  'rosneft',
#  'rosset',
#  'rosseti ural',
#  'rostovoblgaz',
#  'rsti rx',
#  'rtgz',
#  'rtkm rx',
#  'rtsb',
#  'rtsbp',
#  'rual rx',
#  'rusal',
#  'rushydro',
#  'rusi',
#  'russ-invest',
#  'russian public joint-stock commercial roads bank',
#  'samolet',
#  'sber',
#  'sber rx',
#  'sberbank',
#  'segezha',
#  'segezha group',
#  'sfin rx',
#  'sgzh rx',
#  'sibn rx',
#  'smlt rx',
#  'sngs rx',
#  'sollers',
#  'southern kuzbass coal company',
#  'svav rx',
#  'tasb',
#  'tatn rx',
#  'tatneft',
#  'tattelecom',
#  'tcs li',
#  'tgc-1',
#  'tgc-14',
#  'tgc-2',
#  'tgk-1',
#  'tgk-14',
#  'tgk-2',
#  'tgkd',
#  'tmk',
#  'tns energo',
#  'tnse rx',
#  'tors',
#  'transcontainer',
#  'transfin',
#  'transneft',
#  'trcn rx',
#  'trfm',
#  'trmk rx',
#  'trnfp rx',
#  'tuza',
#  'unac rx',
#  'unickel',
#  'unipro',
#  'unkl rx            ',
#  'upro rx',
#  'uralkali',
#  'urals stampings plant',
#  'urka',
#  'urka rx',
#  'utar',
#  'uwgn rx',
#  'vozrozhdenie bank',
#  'vrsb',
#  'vrsbp',
#  'vsmo                ',
#  'vsmpo-avisma',
#  'vsmpo-avisma corporation',
#  'vtb',
#  'vtbr rx',
#  'vzrz rx',
#  'world trade center',
#  'wtc',
#  'wtcm rx',
#  'yakg rx',
#  'yakutskenergo',
#  'yandex',
#  'yatec',
#  'yevropyeyskaya elyektrotyekhnika',
#  'yken rx',
#  'yndx rx',
#  'yrsb',
#  'yrsbp',
#  'zil',
#  'zill                ',
#  'zvez',
#  'zvezda',
#  'абрау – дюрсо',
#  'абрау дюрсо',
#  'авангард',
#  'акб "приморье"',
#  'акб приморье',
#  'акрон',
#  'алроса',
#  'алроса',
#  'ао квадра',
#  'арсагера',
#  'астраханская эсб',
#  'афк система',
#  'аэрофлот',
#  'банк "приморье"',
#  'банк возрождение ',
#  'банк кузнецкий',
#  'банк петербург',
#  'банк приморье',
#  'банк росгосстрах',
#  'банк санкт-петербург',
#  'белон ',
#  'белуга',
#  'бспб',
#  'всмпо-ависма',
#  'втб',
#  'вуш',
#  'вхуш',
#  'газ-тэк',
#  'газпром',
#  'газпром нефть',
#  'газпром рнд',
#  'геотек',
#  'гит',
#  'гк «росбизнесконсалтинг»',
#  'глобалтрак',
#  'городские инновационные технологии',
#  'гр. позитив',
#  'группа "газ"',
#  'группа газ',
#  'группа позитив',
#  'группа самолет',
#  'группа светофор',
#  'дагестанэнергосбыт',
#  'дагсб',
#  'дальневосточная энергетическая компания',
#  'дальневосточное морское пароходство',
#  'двмп',
#  'детмир',
#  'детский мир',
#  'джитиэл',
#  'дзрд',
#  'диод',
#  'донской завод радиодеталей',
#  'дорожный банк',
#  'дэк',
#  'европейская электротехника',
#  'завод имени и.а. лихачева',
#  'завод имени лихачёва ',
#  'завод экологической техники и экопитания диод',
#  'звезда',
#  'зил',
#  'ижевский металлургический завод',
#  'ижсталь',
#  'ик русс-инвест ',
#  'инаркт1р1',
#  'инарктика',
#  'инвест-девелопмент',
#  'инград',
#  'инград (пао)',
#  'институт стволовых клеток человека',
#  'интер рао ',
#  'интер рао еэс финанс',
#  'иркутскэнерго',
#  'иркэнерго',
#  'искч',
#  'казаньоргсинтез',
#  'калужская сбыткомп',
#  'калужская сбытовая компания',
#  'камаз',
#  'квадра',
#  'кгк',
#  'кзмс',
#  'клсб',
#  'ковровский механический завод',
#  'ковровский мехзд',
#  'кокс',
#  'комбинат южуралникель',
#  'корпорация всмпо-ависма',
#  'коршуновский гок',
#  'косогорский металлургический завод',
#  'костромская сбытовая компания',
#  'краснокамский завод металлических сеток',
#  'красноярскэнергосбыт',
#  'красный котельщик ',
#  'кредитные системы',
#  'кск',
#  'кск',
#  'ктк',
#  'кузбасская топливная компания',
#  'кузоцм',
#  'куйбазот',
#  'куйбышевазот',
#  'курганская генерирующая компания',
#  'курганская гк',
#  'левенгук',
#  'лензолото',
#  'липецкая энергосбытовая компания',
#  'липецкая эск',
#  'лср',
#  'лукойл',
#  'лэск',
#  'магнит ',
#  'магнитка',
#  'магнитогорский металлургический комбинат',
#  'мвидео',
#  'мегафон',
#  'мегафон пао',
#  'межрегиональная распределительная сетевая компания урала',
#  'мечел',
#  'мкб',
#  'ммк',
#  'мосбиржа',
#  'московская биржа',
#  'московский кредитный банк',
#  'мостотрест',
#  'мрск урала',
#  'мтс',
#  'мультисистема',
#  'научно-производственное объединение "физика"',
#  'нкхп',
#  'нлмк',
#  'нмтп',
#  'новатэк',
#  'новороссийский комбинат хлебопродуктов',
#  'новороссийский морской порт',
#  'новороссийский морской торговый порт',
#  'новороссийское морское пароходство',
#  'новошип',
#  'норникель',
#  'нпо "физика"',
#  'нпо физика',
#  'оао "смз"',
#  'оао смз',
#  'объединенная авиастроительная корпорация',
#  'объединённая компания "русал"',
#  'одк сатурн',
#  'одк_сатурн',
#  'одк-сатурн',
#  'окс',
#  'ор',
#  'ор групп',
#  'органический синтез',
#  'павл автобус',
#  'павлбус',
#  'павловский автобус',
#  'пао "газ-сервис"',
#  'пао "газ"',
#  'пао "газпром газораспределение ростов-на-дону"',
#  'пао "газпром нефть"',
#  'пао "газпром"',
#  'пао "гит"',
#  'пао "гмк "норильский никель"',
#  'пао "горно-металлургическая компания "норильский никель"',
#  'пао "оак"',
#  'пао «геотек сейсморазведка»',
#  'пао «городские инновационные технологии',
#  'пао «распадская»',
#  'пао «тза»',
#  'пао «южный кузбасс»',
#  'пао банк возрождение',
#  'пао банк кузнецкий',
#  'пао газ',
#  'пао гк тнс энерго',
#  'пао диод ',
#  'пао квадра',
#  'пао кгк',
#  'пао кмз',
#  'пао кмз',
#  'пао кокс',
#  'пао комбинат южуралникель',
#  'пао ктк',
#  'пао магнит',
#  'пао мегафон',
#  'пао оак',
#  'пао россети',
#  'пао русгидро',
#  'пао тза',
#  'пао трансконейнер',
#  'пао фармсинтез',
#  'пао фск еэс',
#  'пао химпром',
#  'пао центральный телеграф',
#  'пао челябинский кузнечно-прессовый завод',
#  'пао чзпсн-профнастил',
#  'пао чмк',
#  'пао чтпз',
#  'пао электроцинк',
#  'пао энел россия',
#  'пао южный кузбасс',
#  'пао юнипро',
#  'пао якутская топливно-энергетическая компания',
#  'пао якутскэнерго',
#  'пермэнергосбыт',
#  'пик сз',
#  'полиметалл',
#  'полюс',
#  'распадская',
#  'рбк',
#  'ргс банк',
#  'рдбанк',
#  'ркк «энергия»',
#  'ркк энергия',
#  'рн-западная сибирь',
#  'роллман',
#  'рос бизнес консалтинг',
#  'росбизнесконсалтинг',
#  'росгосстрах банк',
#  'росинтер',
#  'росинтер ресторантс холдинг',
#  'роснефть',
#  'россет',
#  'россети волга',
#  'россети кубань',
#  'россети ленэнерго',
#  'россети московский регион',
#  'россети северный кавказ',
#  'россети сибирь',
#  'россети томск',
#  'россети урал',
#  'россети фск еэс',
#  'российские сети',
#  'российский акционерный коммерческий дорожный банк',
#  'ростелеком',
#  'ростовоблгаз',
#  'русал',
#  'русгидро',
#  'русс-инвест',
#  'руссинвест',
#  'русская аквакультура',
#  'самолет',
#  'сатурн',
#  'сбер',
#  'сбербанк ',
#  'светофор групп',
#  'северсталь',
#  'северсталь-авто',
#  'сегежа',
#  'сегежа групп',
#  'селигдар',
#  'система',
#  'совкомфлот',
#  'соликамский магниевый завод',
#  'соллерс',
#  'спб банк',
#  'сургутнефтегаз',
#  'тамбовская энергосбытовая компания',
#  'тамбовэнергосбыт',
#  'татнефть',
#  'таттелеком',
#  'тгк-1',
#  'тгк-14',
#  'тгк-2',
#  'тза',
#  'ткз "красный котельщик"',
#  'ткз красный котельщик',
#  'тксм',
#  'тмк',
#  'тнс энерго',
#  'тнс энерго воронеж',
#  'тнс энерго кубань',
#  'тнс энерго марий эл',
#  'тнс энерго нижний новг',
#  'тнс энерго нижний новгород',
#  'тнс энерго ростов',
#  'тнс энерго ростов-на-дону',
#  'тнс энерго ярославль',
#  'томская распределительная компания',
#  'трансконтейнер',
#  'транснефть',
#  'трансфин',
#  'трк',
#  'трубная металлургическая компания',
#  'туймазинский завод автобетоновозов',
#  'тучковский ксм',
#  'уралкалий',
#  'уральская кузница',
#  'фарм-синтез',
#  'фармсинтез',
#  'фосагро',
#  'химпром',
#  'центр международной торговли',
#  'центральный телеграф',
#  'цмт',
#  'челябинский завод профилированного стального настила',
#  'челябинский металлургический комбинат',
#  'челябинский трубопрокатный завод',
#  'черкизово',
#  'чзпсн-профнастил',
#  'чкпз',
#  'чмк',
#  'чтпз',
#  'электроцинк',
#  'эн+ груп',
#  'энел россия',
#  'энергия',
#  'южный кузбасс',
#  'южуралникель',
#  'юнипро',
#  'якутская топливно-энергетическая компания',
#  'якутскэнерго',
#  'ятэк']

# %%
#%%timeit
m = Mystem()
mes_cp_full = mes_012
mes_cp_full = mes_cp_full[['MessageText', 'DatePosted','ticker']]

for i in tqdm(range(mes_cp_full.shape[0])):
    sentences = list(sentenize(mes_cp_full.MessageText[i]))
    markup = ner(mes_cp_full.MessageText[i])
    string = set()
    
    MT = []
    for span in markup.spans:  
        if span.type == 'ORG':
            word = (markup.text[span.start:span.stop]).lower()
            word = m.lemmatize(word)[0]
            if word not in string: # проверка для избежания повторов
                string.add(word)
                ### text boundaries
                for s in sentences:
                    rr = []
                    for r in s: # (rangeL:rangeR), sentence
                        rr.append(r)    
                    if (span.start >= rr[0] and span.stop <= rr[1]):
                        MT.append(rr[2])   
                    
    rows_list = []            
    DP = mes_cp_full.DatePosted[i]
    for s in string:
        c = 0
        new_data = {'MessageText': MT[c], 'DatePosted': DP, 'ticker':s}
        rows_list.append(new_data)
        c+=1
    df = pd.DataFrame(rows_list)
    mes_cp_full = pd.concat([mes_cp_full, df], ignore_index=True)
# Out:
# 100%|██████████| 7538/7538 [03:56<00:00, 31.90it/s]

# %%
mes_cp_full
# Out:
#                                              MessageText          DatePosted  \
# 0      ❗️🛢🇷🇺#газ #россия #макро  Новак: запасы газа н... 2021-12-29 08:51:59
# 1      ПАО «НОВАТЭК» Тикер NVTK Рекомендация - покупк... 2021-12-23 13:38:22
# 2      🟢 НОВАТЭК договорился о поставках низкоуглерод... 2021-12-23 13:31:19
# 3      ☀️ 23.12.2021  📰 Главные темы: • Отбор газа из... 2021-12-23 09:30:01
# 4      🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК поста... 2021-12-23 07:47:03
# ...                                                  ...                 ...
# 40832  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
# 40833  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
# 40834  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
# 40835  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
# 40836  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
#
#            ticker
# 0            nvtk
# 1            nvtk
# 2            nvtk
# 3            nvtk
# 4            nvtk
# ...           ...
# 40832       макро
# 40833        moex
# 40834  северсталь
# 40835        lkoh
# 40836        qiwi
#
# [40837 rows x 3 columns]

# %%
mes_cp_new = mes_cp_full[7538:]
tickers = mes_cp_new['ticker'].tolist()
tickers
# Out:
# ['nvtk',
#  'новатэк',
#  'пао',
#  'uniper',
#  'sbercib',
#  'новатэк',
#  'новатэк',
#  'uniper',
#  'мечесть',
#  'новатэк',
#  'ъ',
#  'казатомпром',
#  'газпром',
#  'цб',
#  'uniper',
#  'новатэк',
#  'uniper',
#  'nvtk',
#  'новатэк',
#  'sbercib',
#  'новатэк',
#  'новатэк',
#  'nvtk',
#  'новатэк',
#  'арктик',
#  'распоряжение',
#  'nvtk',
#  'новатэк',
#  'роснефть',
#  'газпром',
#  'новатэк',
#  'nvtk',
#  'ямал',
#  'nvtk',
#  'новатэк',
#  'новатэк',
#  'лукойл',
#  'илим',
#  'мировой',
#  'новатэк',
#  'немецкий',
#  'rwe',
#  'новатэк',
#  'немецкий',
#  'nvtk',
#  'новатэк',
#  'новатэк',
#  'nvtk',
#  'аэрофлот',
#  'moex',
#  'gltr',
#  'русснефть',
#  'сд',
#  'макро',
#  'softline',
#  'нмтп',
#  'sngs',
#  'татнефть',
#  'фас',
#  'газпром',
#  'акрон',
#  'тмк',
#  'новатэк',
#  'globaltrans',
#  'цб',
#  'smlt',
#  'gazp',
#  'zhejiang',
#  'nvtk',
#  'hibiki',
#  'новатэк',
#  'petrovietnam',
#  'saibu',
#  'афк',
#  'новатэк',
#  'опек+',
#  'новатэк',
#  'яндекс',
#  'овк',
#  'новатэк',
#  'ozon',
#  '02',
#  'ммвб',
#  'sbercib',
#  'sber',
#  'банк',
#  'альфа-банк',
#  'райффайзенбанк',
#  'sber',
#  'газпромбанк',
#  'втб',
#  'совкомбанк',
#  'sber',
#  'газпромбанк',
#  'московский',
#  'бк',
#  'банк',
#  'альфа-банк',
#  'bcs',
#  'sber',
#  'пво',
#  'лигал',
#  'мосбиржа',
#  'nasdaq',
#  'индекс',
#  'минэнерго',
#  'dow',
#  's',
#  'sbercib',
#  'рука',
#  'меретояханефтегаз',
#  'газпром',
#  'лукойл',
#  'sber',
#  'сбер',
#  'sber',
#  'группа',
#  'сбербанк',
#  'сбер',
#  'sbercib',
#  'нлмк',
#  'банк',
#  'мосбиржа',
#  'индекс',
#  'американский',
#  'минэнерго',
#  'sbercib',
#  'sbercib',
#  'сберинвестиция',
#  'газпром',
#  'sbercib',
#  'итогиразмещение',
#  'газпромбанк',
#  'мосбиржа',
#  'sbercib',
#  'нато',
#  'nvidia',
#  'top',
#  'газпром',
#  'x5',
#  'sbercib',
#  'gazp',
#  'sbercib',
#  'фрс',
#  'фнб',
#  'цб',
#  'мосбиржа',
#  'индекс',
#  'нато',
#  'втб',
#  'sber',
#  'газпромбанк',
#  'совкомбанк',
#  'нкр',
#  'morgan',
#  'sberbank',
#  'jpmorgan',
#  'рдв',
#  'yndx',
#  'яндекс',
#  'сбер',
#  'sber',
#  'сбербанк',
#  'sbercib',
#  'сберинвестиция',
#  'ice',
#  'мосбиржа',
#  'sbercib',
#  'sberbank',
#  'мосбиржа',
#  'micron',
#  'sbercib',
#  'нлмк',
#  'uniper',
#  'sbercib',
#  'новатэк',
#  'управление',
#  'baker',
#  'мосбиржа',
#  'sbercib',
#  'sbercib',
#  'нлмк',
#  'казатомпром',
#  'газпром',
#  'цб',
#  'sbercib',
#  'сберинвестиция',
#  'sbercib',
#  'детский',
#  'зоозавр',
#  'sberbank',
#  'газпром',
#  'совкомфлот',
#  'sber',
#  'vtbr',
#  'msci',
#  'small',
#  'trnf',
#  'ммк',
#  'лукойл',
#  'русгидро',
#  'pikk',
#  'tcs',
#  'сбер',
#  'м',
#  'газпром',
#  'пик',
#  'magn',
#  'investfuture',
#  'транснефть',
#  'vk',
#  'gazp',
#  'газпром',
#  'sbercib',
#  'gazp',
#  'банк',
#  'россельхозбанк',
#  'синара',
#  'втб',
#  'аренз',
#  'бизнес',
#  'газпромбанк',
#  'инвестбанк',
#  'мтс',
#  'sbercib',
#  'бк',
#  'мосбиржа',
#  'управление',
#  'менеджмент',
#  'нато',
#  'sbercib',
#  'сбермаркет',
#  'sber',
#  'metro',
#  'сд',
#  'sber',
#  'rosn',
#  'газпром',
#  'gazp',
#  'sbercib',
#  'sbercib',
#  'банк',
#  'рсхб',
#  'втб',
#  'sber',
#  'газпромбанк',
#  'бк',
#  'fitch',
#  'полюс',
#  'moody',
#  's',
#  'sbercib',
#  'вэб',
#  'банк',
#  'альфа-банк',
#  'инкаб',
#  'гк',
#  'bcs',
#  'ифк',
#  'втб',
#  'сопф',
#  'совкомбанк',
#  'газпромбанк',
#  'инвестбанк',
#  'sbercib',
#  'sber',
#  'сбербанк',
#  'sber',
#  'сбербанк',
#  'ситибанка',
#  'sber',
#  'сбербанк',
#  'прайм',
#  'sber',
#  'мосбиржа',
#  'минфин',
#  'sbercib',
#  'американский',
#  'ъ',
#  'яндекс',
#  'horeca',
#  'sber',
#  'ozon',
#  'банк',
#  'micron',
#  'федрезерв',
#  'top',
#  'sbercib',
#  'sbercib',
#  'лукойл',
#  'опек+',
#  'sbercib',
#  'новатэк',
#  'втб',
#  'sber',
#  'райффайзенбанк',
#  'банк',
#  'мосбиржа',
#  'фрс',
#  'sbercib',
#  'втб',
#  'аэрофлот',
#  'яндекс',
#  'covid',
#  'repsol',
#  'cnn',
#  'газпром',
#  'рбк',
#  'sber',
#  'сбер',
#  'яндекс',
#  'аэрофлот',
#  'beluga',
#  'втб',
#  'remy',
#  'фас',
#  'газпромнефть',
#  'сбер',
#  'газпром',
#  'роснефть',
#  'сбербанк',
#  'сбербанк',
#  'снг',
#  'сбер',
#  'магнит',
#  'дикси',
#  'лента',
#  'билл',
#  'google',
#  'facebook',
#  'm',
#  'сп',
#  'сбер',
#  'e',
#  'vk',
#  'сбербанк',
#  'фск',
#  'рсхб',
#  'транснефть',
#  'ржд',
#  'газпром',
#  'росбанк',
#  'мтс',
#  'роснефть',
#  'sbercib',
#  'вэб',
#  'альфа-банк',
#  'втб',
#  'ик',
#  'северсталь',
#  'цб',
#  'adobe',
#  'банк',
#  'sbercib',
#  'цб',
#  'sberinvestments',
#  'сберинвестиция',
#  'sberinvestments',
#  'сберинвестиция',
#  'sberinvestments',
#  'сберинвестиция',
#  'bloomberg',
#  'банк',
#  'мосбиржа',
#  'цб',
#  'роснефть',
#  'sbercib',
#  'morgan',
#  'sberbank',
#  'jpmorgan',
#  'рдв',
#  'sbercib',
#  'втб',
#  'sber',
#  'сбербанк',
#  'газпром',
#  'sbercib',
#  'gazp',
#  'мосбиржа',
#  'сбер',
#  'sber',
#  'мсфо',
#  'газпром',
#  'sber',
#  'сбер',
#  'мосбиржа',
#  'фрс',
#  'sber',
#  'ъ',
#  'роснано',
#  'мосбиржа',
#  'евраза',
#  'сургутнефтегаз',
#  'сбербанк',
#  'распадской',
#  'sber',
#  'тасс',
#  'сбер',
#  'основныесобытие',
#  'сбербанк',
#  'инвестбанк',
#  'sbercib',
#  'sber',
#  'сотрудничать',
#  'партнерский',
#  'сбер',
#  'sber',
#  'банк',
#  'дивиденд',
#  'sber',
#  'продавать',
#  'иностранный',
#  'греф',
#  'sber',
#  'финдиректор',
#  'sber',
#  'сбербанк',
#  'финансовый',
#  'sber',
#  'sber',
#  'sber',
#  'sber',
#  'sber',
#  'интерфакс',
#  'sber',
#  'сбербанк',
#  'подтверждать',
#  'sber',
#  'sber',
#  'сбер',
#  'sber',
#  'sber',
#  'сбер',
#  'sber',
#  'sber',
#  'sber',
#  'sber',
#  'sber',
#  'sber',
#  'тасс',
#  'сбер',
#  'kimberly',
#  'lockheed',
#  'яндекс',
#  'johnson',
#  'полюс',
#  'сбер',
#  'северсталь',
#  'microsoft',
#  'норникель',
#  'ммк',
#  'procter',
#  'tyson',
#  'bunge',
#  'мтс',
#  'россеть',
#  'газпром',
#  'x5',
#  'лукойл',
#  'банк',
#  'ик',
#  'акр',
#  'атон',
#  'совкомбанк',
#  'цб',
#  'росбанк',
#  'макроэкономика',
#  'sbercib',
#  'федрезерв',
#  'sbercib',
#  'фрс',
#  'банк',
#  'мосбиржа',
#  'индекс',
#  'федрезерв',
#  'брент',
#  'sbercib',
#  'фрс',
#  'лукойл',
#  'сбербанк',
#  'фрс',
#  'five',
#  'макро',
#  'upro',
#  'фосагро',
#  'цб',
#  'phor',
#  'sber',
#  'фн',
#  'lkoh',
#  'фрс',
#  'square',
#  'coinbase',
#  'sbercib',
#  'paypal',
#  'афк',
#  'мосбиржа',
#  'интерфакс',
#  'газпром',
#  'русала',
#  'тинькофф',
#  'sber',
#  'сбербанк',
#  'bank',
#  'sbercib',
#  'hsbc',
#  'цб',
#  'msci',
#  'sbercib',
#  'газпром',
#  'опек+',
#  'мосбиржа',
#  'индекс',
#  'pfizer',
#  'мэа',
#  'минфин',
#  'astrazeneca',
#  'опек',
#  'sbercib',
#  'фрс',
#  'five',
#  'макро',
#  'upro',
#  'фосагро',
#  'phor',
#  'sber',
#  'фн',
#  'фрс',
#  'mvid',
#  'sber',
#  'мосбиржа',
#  'ростелеком',
#  'ецб',
#  'mail',
#  'vk',
#  'газпром',
#  'фрс',
#  'sbercib',
#  'совет',
#  'inditex',
#  'delta',
#  'сбербанк',
#  'русала',
#  'мтс',
#  'intema',
#  'visionlabs',
#  'сбер',
#  'top',
#  'газпром',
#  'фрс',
#  'sbercib',
#  'gazp',
#  'visionlabs',
#  'сбер',
#  'intema',
#  'мтс',
#  'сбербанк',
#  'альфа-банк',
#  'цб',
#  'sberbank',
#  'алроса',
#  'фрс',
#  'транснефть',
#  'sbercib',
#  'sber',
#  'газпром',
#  'сбер',
#  'банк',
#  'sbercib',
#  'цб',
#  'ифк',
#  'инвестиционный',
#  'совкомбанк',
#  'sber',
#  'пво',
#  'iti',
#  'мосбиржа',
#  'цб',
#  'опек',
#  'sbercib',
#  'минфин',
#  'five',
#  'макро',
#  'upro',
#  'фосагро',
#  'цб',
#  'phor',
#  'sber',
#  'lkoh',
#  'опек',
#  'gemc',
#  'фрс',
#  'mvid',
#  'sber',
#  'международный',
#  'дочка',
#  'sbercib',
#  'sbercib',
#  's',
#  'основныесобытие',
#  'инвестбанк',
#  'sbercib',
#  'котировка',
#  'sberbank',
#  'транснефть',
#  'банк',
#  'ик',
#  'цб',
#  'sberbank',
#  'убрир',
#  'сбербанк',
#  'лукойл',
#  'цб',
#  'sbercib',
#  'цбр',
#  'мосбиржа',
#  'micron',
#  'сбербанк',
#  'amazon',
#  'аэрофлот',
#  'facebook',
#  'meta',
#  'microsoft',
#  'норникель',
#  'газпром',
#  'лукойл',
#  'gazp',
#  'газпром',
#  'sbercib',
#  'втб',
#  'инк',
#  'райффайзенбанк',
#  'sbercib',
#  'sber',
#  'мсфо',
#  'сбербанк',
#  'мосбиржа',
#  'sbercib',
#  'нато',
#  'sber',
#  'сбербанк',
#  'sber',
#  'сбербанк',
#  'соллерс',
#  '#',
#  'sber',
#  'нато',
#  'сбербанк',
#  'ртс',
#  'jpmorgan',
#  'фосагро',
#  'сбер',
#  'рдв',
#  'газпром',
#  'фрс',
#  'morgan',
#  'sberbank',
#  'jpmorgan',
#  'рдв',
#  'сбп',
#  'рдв',
#  'снг',
#  'swift',
#  'рдв',
#  'swift',
#  'акция',
#  'рф',
#  'цб',
#  'у',
#  'газпром',
#  'тинькофф',
#  'сбербанк',
#  'сбер',
#  'пао',
#  'sberbank',
#  'sberbank',
#  'альфа-банк',
#  'газпромбанк',
#  'цб',
#  'прайм',
#  'sber',
#  'мсфо',
#  'консенсус',
#  'сбербанк',
#  'sber',
#  'сбербанк',
#  'мосбиржа',
#  'sbercib',
#  'нато',
#  'сбербанк',
#  'marketoverview',
#  'sber',
#  'сбербанк',
#  'илим',
#  'мировой',
#  'цб',
#  'sber',
#  'сбер',
#  'sber',
#  'сбербанк',
#  'sber',
#  'sber',
#  'сбер',
#  'sber',
#  'сбер',
#  'банк',
#  'sbercib',
#  'цб',
#  'втб',
#  'sber',
#  'газпромбанк',
#  'московский',
#  'бк',
#  'альфа-банк',
#  'veon',
#  'сбер',
#  'sberbank',
#  'ммк',
#  'сбербанк',
#  'sflt',
#  'microsoft',
#  'm',
#  'softline',
#  'sbercib',
#  'снг',
#  'сбер',
#  'sber',
#  'сбербанк',
#  'синара',
#  'ифк',
#  'первый',
#  'совкомбанк',
#  'пво',
#  's',
#  'iti',
#  'sbercib',
#  'sber',
#  'мосбиржа',
#  'управление',
#  'американский',
#  'ецб',
#  'цб',
#  'sbercib',
#  'тасс',
#  'cognitive',
#  'сбер',
#  'сбербанк',
#  'сбер',
#  'ъ',
#  'yndx',
#  'яндекс',
#  'втб',
#  'сбер',
#  'sber',
#  'vk',
#  'мтс',
#  'mtss',
#  'сбербанк',
#  'sber',
#  'сбер',
#  'sber',
#  'sber',
#  'сбер',
#  'sberbank',
#  'опек+',
#  'сд',
#  'sber',
#  'сбер',
#  'sber',
#  'тасс',
#  'vk',
#  'сбер',
#  'греф',
#  'цб',
#  'надеяться',
#  'sber',
#  'сбербанк',
#  'экспертра',
#  'втб',
#  'совкомбанк',
#  'газпромбанк',
#  'sbercib',
#  'sbercib',
#  'лукойл',
#  'синара',
#  'ифк',
#  'пкб',
#  'совкомбанк',
#  'sber',
#  'iti',
#  'sber',
#  'vtbr',
#  'рбк',
#  'управление',
#  'ммк',
#  'мосбиржа',
#  'sbercib',
#  'sber',
#  'отчетность',
#  'сбер',
#  'sber',
#  'сбербанк',
#  'отчетность',
#  'bloomberg',
#  'афк',
#  'amazon',
#  'цб',
#  'минфин',
#  'vk',
#  'фрс',
#  'alrs',
#  'chmf',
#  'макро',
#  'ипц',
#  'sber',
#  'фн',
#  'алроса',
#  'мосбиржа',
#  'ppd',
#  'компания',
#  'sber',
#  'eia',
#  'toll',
#  'thermo',
#  'api',
#  'magn',
#  'мосбиржа',
#  'ppd',
#  'tol',
#  'veon',
#  'газ',
#  'zew',
#  'цб',
#  'сегодня',
#  'sber',
#  'eia',
#  'toll',
#  'thermo',
#  'api',
#  'минфин',
#  'магнит',
#  'yndx',
#  'макро',
#  'цб',
#  'mgnt',
#  'sber',
#  'marathon',
#  'норникель',
#  'lkoh',
#  'сбербанк',
#  'top',
#  'sbercib',
#  'segezha',
#  'merck',
#  'инк',
#  'райффайзенбанк',
#  'втб',
#  'основныесобытие',
#  'sbercib',
#  'sber',
#  'сбербанк',
#  'инвестиционный',
#  'sber',
#  'газпромбанк',
#  'московский',
#  'бк',
#  'тинькофф',
#  'облигация',
#  'овк',
#  'global',
#  'подробно',
#  'рнпк',
#  'сбербанк',
#  'мосбиржа',
#  'сми',
#  'опек',
#  'фонд',
#  'sbercib',
#  'magn',
#  'alrs',
#  'chmf',
#  'макро',
#  'ипц',
#  'moex',
#  'sber',
#  'фн',
#  'алроса',
#  'magn',
#  'alrs',
#  'chmf',
#  'макро',
#  'ипц',
#  'moex',
#  'sber',
#  'фн',
#  'алроса',
#  'русский',
#  'sbercib',
#  'воркутауголь',
#  'северсталь',
#  'sber',
#  'сбер',
#  'банк',
#  'мосбиржа',
#  'fitch',
#  'цб',
#  'moody',
#  'sbercib',
#  'фрс',
#  'chmf',
#  'moex',
#  'sber',
#  'фн',
#  'алроса',
#  'morgan',
#  'sberbank',
#  'jpmorgan',
#  'рдв',
#  'татнефть',
#  'sberbank',
#  'sberbank',
#  'chevron',
#  'оон',
#  'норникель',
#  'сбер',
#  'нпз',
#  'мсфо',
#  'газпром',
#  '✅',
#  'tcsg',
#  'tcs',
#  'sbercib',
#  'банк',
#  'мосбиржа',
#  'мид',
#  'опек+',
#  'sbercib',
#  'фрс',
#  'afks',
#  'афк',
#  'chmf',
#  'moex',
#  'северсталь',
#  'sber',
#  'lkoh',
#  'qiwi',
#  'афк',
#  'five',
#  'sber',
#  'самолет',
#  'x5',
#  'цб',
#  'основныесобытие',
#  'инвестбанк',
#  'sbercib',
#  'plzl',
#  'национальный',
#  'полюс',
#  'сбер',
#  'sber',
#  'sber',
#  'сбербанк',
#  'роснано',
#  'аэрофлот',
#  'опек+',
#  'sberbank',
#  'газпромбанк',
#  'интерфакс',
#  'транснефть',
#  'sbercib',
#  'сбербанк',
#  'сбер',
#  'пао',
#  'конгресс',
#  'мосбиржа',
#  'ипц',
#  'опек+',
#  'вто',
#  'нато',
#  'sbercib',
#  'фрс',
#  'магнит',
#  'лента',
#  'новостикомпания',
#  'ик',
#  'ozon',
#  'fix',
#  'x5',
#  'московский',
#  'магнит',
#  'five',
#  'if',
#  'mgnt',
#  'fix',
#  'x5',
#  'альфа',
#  'bloomberg',
#  'втб',
#  'ренессанс',
#  'рдв',
#  ...]

# %%
# !wget https://drive.google.com/file/d/1DNilv-qiNFjCSOhBFZE4JjGbSrAYZ9UP/view?usp=sharing
# Out:
# --2023-11-21 10:12:05--  https://drive.google.com/file/d/1DNilv-qiNFjCSOhBFZE4JjGbSrAYZ9UP/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 74.125.195.101, 74.125.195.113, 74.125.195.102, ...
# Connecting to drive.google.com (drive.google.com)|74.125.195.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing’
#
# view?usp=sharing        [ <=>                ]  82.47K  --.-KB/s    in 0.005s
#
# 2023-11-21 10:12:06 (16.2 MB/s) - ‘view?usp=sharing’ saved [84445]

# %%
brands = pd.read_csv('../input/brands-without-rx/all brands - Sheet2.csv') # brands - все issuers(кроме полных названий) с повторами.
brands['abraudurso'] = brands['abraudurso'].str.lower()
brand_list = brands.abraudurso.tolist()

# %%
def sw_info_save(tickers,brand_list):
    stopwords = []
    for ticker in tickers:
        if ticker not in brand_list:
            stopwords.append(ticker)
    print("количество стоп слов:",len(stopwords))
    ssw_set = sorted(set(stopwords))
    print("количество уникальных стоп слов:",len(ssw_set))
    with open("stopwords.txt", 'w') as output:
        output.write(str(list(ssw_set)))
        print("file saved as stopwords.txt")
    return ssw_set

# %%
ssw_set = sw_info_save(tickers,brand_list)
# Out:
# количество стоп слов: 24132
# количество уникальных стоп слов: 1710
# file saved as stopwords.txt

# %% [markdown]
# ## Уберем RX из issuers и добавим set стоп слов (быстрее чем list)

# %%
m = Mystem()
mes_cp_full = mes_012
mes_cp_full = mes_cp_full[['MessageText', 'DatePosted','ticker']]

for i in tqdm(range(mes_cp_full.shape[0])):
    sentences = list(sentenize(mes_cp_full.MessageText[i]))
    markup = ner(mes_cp_full.MessageText[i])
    string = set()
    
    MT = []
    for span in markup.spans:  
        if span.type == 'ORG':
            word = (markup.text[span.start:span.stop]).lower()
            word = m.lemmatize(word)[0]
            if word not in ssw_set:
                if word not in string: # проверка,чтобы избежать повторы
                    ### text boundaries
                    for s in sentences:
                        rr = []
                        for r in s: # (rangeL:rangeR), sentence
                            rr.append(r)    
                        if (span.start >= rr[0] and span.stop <= rr[1]):
                            MT.append(rr[2])
                            string.add(word) # добавляем слово только если для него есть предложение
                #if word in string   
    rows_list = []            
    DP = mes_cp_full.DatePosted[i]
    for c,s in enumerate(string):
        new_data = {'MessageText': MT[c], 'DatePosted': DP, 'ticker':s}
        rows_list.append(new_data)
    df = pd.DataFrame(rows_list)
    mes_cp_full = pd.concat([mes_cp_full, df], ignore_index=True)
# Out:
# 100%|██████████| 7538/7538 [03:51<00:00, 32.50it/s]

# %%
mes_cp_new = mes_cp_full[7538:]
mes_cp_new
# Out:
#                                              MessageText          DatePosted  \
# 7538   Фундаментальный фактор Основным позитивным мом... 2021-12-23 13:38:22
# 7539   🟢 НОВАТЭК договорился о поставках низкоуглерод... 2021-12-23 13:31:19
# 7540   • Новатэк (NVTK) заключил соглашение об экспор... 2021-12-23 09:30:01
# 7541   🇷🇺🇪🇺#NVTK #водород #аэ  #европа  НОВАТЭК поста... 2021-12-23 07:47:03
# 7542        Главный бенефициар сектора - Газпром (GAZP). 2021-12-22 19:29:59
# ...                                                  ...                 ...
# 16675  🔦 Фокус недели #ФН   Сегодня 🖨 Мосбиржа (MOEX)... 2021-12-02 08:01:34
# 16676  🔦 Фокус недели #ФН   Сегодня 🖨 Мосбиржа (MOEX)... 2021-12-02 08:01:34
# 16677  Компания Самолет (SMLT) провела первый День Ин... 2021-12-01 19:00:00
# 16678  Кроме этого, маржинальность ритейлеров может с... 2021-12-01 19:00:00
# 16679  🔦 Фокус недели #ФН   Сегодня 🌎 Вступают в силу... 2021-12-01 08:02:12
#
#            ticker
# 7538      новатэк
# 7539      новатэк
# 7540      новатэк
# 7541      новатэк
# 7542      газпром
# ...           ...
# 16675        sber
# 16676  северсталь
# 16677        sber
# 16678     самолет
# 16679  северсталь
#
# [9142 rows x 3 columns]

# %% [markdown]
# ### Есть баг: if (span.start >= rr[0] and span.stop <= rr[1]): не всегда выполняется(хотя если слово есть, то для него найдется предложение)
# ### не понятно,как фиксить - кроме как добавлять слово, только если для него есть предложение

# %% [markdown]
# # TODO
# ### добавить prev_start, prev_stop, подумать, как дать токену больше чем одно предложение: 1) либо разделение для n, либо вместо MT = [], сделать словарь, MT[word] = concat(sentence, s2), если s2 содержит word(ключ), который уже есть в словаре.
#
# 1. ### сделать суперстроки для issuers
# ### word in string - добавить предложение в MT
